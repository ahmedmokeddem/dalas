# %%
import pandas as pd
import numpy as np

# %%
# importer les datasets a merge
df_nb_heureTravail=pd.read_csv("../datasets_dw/Racha/df_nb_heureTravail_primaire_college.csv", sep=';')
df_nb_semaines_conge=pd.read_csv("../datasets_dw/Racha/df_nb_semaines_conge.csv",  sep=';')
df_imigration=pd.read_csv("../datasets_dw/Racha/immigration-by-country-2024.csv")
df_political_regime=pd.read_csv("../datasets_dw/Racha/political-regime.csv")

df_nbPrix_musees_anneeSouv=pd.read_csv("../datasets_scraped/df_nbPrix_musees_anneeSouv.csv")

# %%
def has_common_name(liste_mots1, liste_mots2):
    
    liste_mots_communs=set()

    # Vérifier si on a au moins un mot en commun
    for mot in liste_mots1:
        if mot in liste_mots2:
            liste_mots_communs.add(mot)
    return liste_mots_communs

# %% [markdown]
# ## Merge dataset polical_regime

# %%
# Recuperer les pays et leur régime politique pour l'année 2019
df_political_regime_2019=df_political_regime.loc[df_political_regime.Year==2019, ['Entity','Political regime']]
df_political_regime_2019.rename(columns={"Entity":"Pays"}, inplace=True)
df_political_regime_2019
# Out:
#               Pays  Political regime
# 229    Afghanistan                 1
# 338        Albania                 1
# 459        Algeria                 1
# 582         Angola                 1
# 816      Argentina                 2
# ...            ...               ...
# 30022      Vietnam                 0
# 30313        Yemen                 0
# 30516       Zambia                 1
# 30639     Zanzibar                 1
# 30762     Zimbabwe                 1
#
# [178 rows x 2 columns]

# %%
df_nbPrix_musees_anneeSouv_PR=df_nbPrix_musees_anneeSouv.set_index('Pays').join(df_political_regime_2019.set_index('Pays'))
df_nbPrix_musees_anneeSouv_PR_nan=df_nbPrix_musees_anneeSouv_PR[df_nbPrix_musees_anneeSouv_PR['Political regime'].isna()]
print("Le nombre de pays sans l'information sur le régime politique : ",np.sum(df_nbPrix_musees_anneeSouv_PR_nan['Political regime'].isna()))
df_nbPrix_musees_anneeSouv_PR_nan
# Out:
# Le nombre de pays sans l'information sur le régime politique :  30
#                                                                        Notes_musees  \
# Pays
# Andorra                           ['4,5', '4,5', '4,6', '4,4', '4,5', '4,7', '4,...
# Antigua and Barbuda                                                         ['4.2']
# Bahamas                           ['4,4', '4,8', '4,4', '4,8', '4,7', '4,2', '4,...
# Belize                                                                      ['4.4']
# Bermuda                           ['4.6', '4.6', '4.3', '4.3', '4.7', '4.6', '4....
# British Virgin Islands                          ['4.7', '4.4', '5.0', '2.5', '3.8']
# Brunei                            ['4,4', '4,0', '4,6', '3,8', '4,5', '3,8', '4,...
# Cayman Islands                                                       ['4.5', '4.6']
# Cook Islands                                           ['4.5', '4.8', '4.0', '4.4']
# Czech Republic                    ['4,5', '4,6', '4,1', '4,6', '4,1', '4,3', '4,...
# Dominica                                                                    ['4.3']
# Greenland                         ['4,5', '4,3', '4,1', '4,5', '4,8', '4,0', '4,...
# Grenada                                                ['4.1', '4.2', '4.5', '4.2']
# Ivory Coast                                     ['3,9', '4,0', '3,8', '4,4', '3,9']
# Kiribati                                                                    ['4.0']
# Liechtenstein                     ['4.6', '4.3', '3.7', '4.3', '4.2', '4.3', '4....
# Macau                             ['4,2', '4,3', '3,7', '4,0', '4,4', '4,2', '4,...
# Marshall Islands                                                            ['4.2']
# Micronesia                        ['4.1', '4.4', '4.6', '3.5', '5.0', '4.3', '4.3']
# New Caledonia                     ['4,3', '4,4', '4,5', '3,9', '4,6', '4,5', '4,...
# Northern Mariana Islands                                                    ['4.4']
# Palestine                         [4.3, 4.8, 4.4, 4.5, 4.3, 4.6, 4.4, 4.7, 4.7, ...
# Puerto Rico                       ['4.7', '4.6', '4.6', '4.6', '4.7', '4.5', '4....
# Republic of the Congo                                         ['4,1', '4,6', '4,3']
# Saint Kitts and Nevis                           ['4.4', '4.6', '4.8', '4.6', '3.5']
# Saint Lucia                       ['4.0', '4.2', '5.0', '4.6', '4.0', '4.2', '4....
# Saint Vincent and the Grenadines                                     ['4.8', '3.9']
# Samoa                                                                ['3.7', '4.7']
# Tonga                                                                       ['3.8']
# Turks and Caicos Islands                        ['4.4', '4.6', '5.0', '3.8', '4.6']
#
#                                                                NbVotes_musees_clean  \
# Pays
# Andorra                           [383.0, 563.0, 153.0, 421.0, 193.0, 56.0, 128....
# Antigua and Barbuda                                                         [388.0]
# Bahamas                           [60.0, 11.0, 1000.0, 28.0, 61.0, 9.0, 23.0, 37...
# Belize                                                                      [424.0]
# Bermuda                           [691.0, 8.0, 21.0, 12.0, 22.0, 34.0, 257.0, 8....
# British Virgin Islands                                   [26.0, 7.0, 1.0, 2.0, 5.0]
# Brunei                             [821.0, 215.0, 33.0, 68.0, 49.0, 28.0, 2.0, 2.0]
# Cayman Islands                                                       [232.0, 130.0]
# Cook Islands                                               [103.0, 9.0, 32.0, 42.0]
# Czech Republic                    [33000.0, 1000.0, 6000.0, 16000.0, 6000.0, 100...
# Dominica                                                                     [65.0]
# Greenland                         [282.0, 197.0, 11.0, 33.0, 43.0, 18.0, 9.0, 28...
# Grenada                                                   [58.0, 12.0, 13.0, 114.0]
# Ivory Coast                                        [764.0, 564.0, 565.0, 76.0, 8.0]
# Kiribati                                                                      [1.0]
# Liechtenstein                     [280.0, 645.0, 64.0, 260.0, 17.0, 22.0, 18.0, ...
# Macau                             [491.0, 248.0, 30.0, 470.0, 23.0, 183.0, 60.0,...
# Marshall Islands                                                             [34.0]
# Micronesia                                 [7.0, 49.0, 263.0, 2.0, 1.0, 7.0, 354.0]
# New Caledonia                     [86.0, 668.0, 112.0, 9.0, 121.0, 4.0, 32.0, 11...
# Northern Mariana Islands                                                     [70.0]
# Palestine                         [386.0, 49.0, 132.0, 440.0, 270.0, 717.0, 36.0...
# Puerto Rico                       [2000.0, 559.0, 765.0, 559.0, 2000.0, 300.0, 3...
# Republic of the Congo                                           [230.0, 38.0, 87.0]
# Saint Kitts and Nevis                               [110.0, 64.0, 151.0, 21.0, 6.0]
# Saint Lucia                       [6.0, 14.0, 1.0, 13.0, 26.0, 47.0, 3.0, 144.0,...
# Saint Vincent and the Grenadines                                      [19.0, 154.0]
# Samoa                                                                 [32.0, 107.0]
# Tonga                                                                        [12.0]
# Turks and Caicos Islands                               [187.0, 36.0, 4.0, 9.0, 7.0]
#
#                                   Nb_prixNobel  Annee_souverainete  \
# Pays
# Andorra                                    0.0                 NaN
# Antigua and Barbuda                        0.0                 NaN
# Bahamas                                    0.0              1964.0
# Belize                                     0.0              1981.0
# Bermuda                                    0.0                 NaN
# British Virgin Islands                     0.0                 NaN
# Brunei                                     0.0              1984.0
# Cayman Islands                             0.0                 NaN
# Cook Islands                               0.0                 NaN
# Czech Republic                             6.0              1918.0
# Dominica                                   0.0                 NaN
# Greenland                                  0.0                 NaN
# Grenada                                    0.0                 NaN
# Ivory Coast                                0.0              1958.0
# Kiribati                                   0.0              1979.0
# Liechtenstein                              0.0              1813.0
# Macau                                      0.0                 NaN
# Marshall Islands                           0.0              1986.0
# Micronesia                                 0.0                 NaN
# New Caledonia                              0.0                 NaN
# Northern Mariana Islands                   0.0                 NaN
# Palestine                                  1.0                 NaN
# Puerto Rico                                0.0                 NaN
# Republic of the Congo                      0.0                 NaN
# Saint Kitts and Nevis                      0.0                 NaN
# Saint Lucia                                2.0                 NaN
# Saint Vincent and the Grenadines           0.0                 NaN
# Samoa                                      0.0              1962.0
# Tonga                                      0.0              1970.0
# Turks and Caicos Islands                   0.0                 NaN
#
#                                   Political regime
# Pays
# Andorra                                        NaN
# Antigua and Barbuda                            NaN
# Bahamas                                        NaN
# Belize                                         NaN
# Bermuda                                        NaN
# British Virgin Islands                         NaN
# Brunei                                         NaN
# Cayman Islands                                 NaN
# Cook Islands                                   NaN
# Czech Republic                                 NaN
# Dominica                                       NaN
# Greenland                                      NaN
# Grenada                                        NaN
# Ivory Coast                                    NaN
# Kiribati                                       NaN
# Liechtenstein                                  NaN
# Macau                                          NaN
# Marshall Islands                               NaN
# Micronesia                                     NaN
# New Caledonia                                  NaN
# Northern Mariana Islands                       NaN
# Palestine                                      NaN
# Puerto Rico                                    NaN
# Republic of the Congo                          NaN
# Saint Kitts and Nevis                          NaN
# Saint Lucia                                    NaN
# Saint Vincent and the Grenadines               NaN
# Samoa                                          NaN
# Tonga                                          NaN
# Turks and Caicos Islands                       NaN

# %%
# Identifier les mots en communs entre le dataset que nous voulons join et celui des pays sans correspondance (retrouver les pays mal etiquetés)
df_nbPrix_musees_anneeSouv_PR_nan.reset_index(inplace=True)
liste_pays1=list(df_nbPrix_musees_anneeSouv_PR_nan.Pays.apply(lambda x : x.split()))
liste_pays1=[mot for sublist in liste_pays1 for mot in sublist]

liste_pays2=list(df_political_regime_2019.Pays.apply(lambda x : x.split()))
liste_pays2=[mot for sublist in liste_pays2 for mot in sublist]

liste_mots_communs=has_common_name(liste_pays1,liste_pays2)
liste_mots_communs
# Out:
# {'Congo', 'Islands', 'New', 'Republic', 'and', 'of'}

# %%
# Mettre a jour le nom des pays de sorte à ce qu'ils correspondent à ceux du dataset musée
dict_convertNomPays={"Palestine/Gaza":"Palestine"}
df_political_regime_2019.Pays=df_political_regime_2019.Pays.apply(lambda x : dict_convertNomPays[x] if x in dict_convertNomPays else x)
df_political_regime_2019[df_political_regime_2019.Pays=='Palestine']
# Out:
#             Pays  Political regime
# 20844  Palestine                 0

# %%
#df_nbPrix_musees_anneeSouv.reset_index(inplace=True)
df_nbPrix_musees_anneeSouv_PR_final=df_nbPrix_musees_anneeSouv.set_index('Pays').join(df_political_regime_2019.set_index('Pays'))
print("Le nombre de pays sans l'information sur le régime politique : ",np.sum(df_merged1['Political regime'].isna()))
# Out:
# Le nombre de pays sans l'information sur le régime politique :  29

# %%
df_merged1=df_nbPrix_musees_anneeSouv_PR_final.copy()
df_merged1
# Out:
#                                                   Notes_musees  \
# Pays
# Afghanistan                                              [4.5]
# Albania      ['4,1', '4,4', '4,6', '4,6', '4,4', '4,7', '4,...
# Algeria      ['4,4', '4,6', '4,4', '4,3', '4,7', '4,6', '4,...
# Andorra      ['4,5', '4,5', '4,6', '4,4', '4,5', '4,7', '4,...
# Angola       ['4,8', '4,2', '4,1', '3,9', '4,3', '4,5', '4,...
# ...                                                        ...
# Venezuela    ['4,2', '4,5', '4,4', '4,3', '4,7', '4,2', '4,...
# Vietnam                                                     []
# Yemen        ['4.4', '4.4', '4.2', '5.0', '5.0', '4.8', '4....
# Zambia       ['4.3', '4.2', '3.7', '4.3', '3.8', '3.9', '3....
# Zimbabwe     ['3.8', '4.1', '4.3', '3.8', '4.1', '4.0', '4....
#
#                                           NbVotes_musees_clean  Nb_prixNobel  \
# Pays
# Afghanistan                                            [574.0]           0.0
# Albania      [1000.0, 1000.0, 471.0, 1000.0, 3000.0, 259.0,...           0.0
# Algeria      [250.0, 545.0, 790.0, 199.0, 170.0, 348.0, 240...           2.0
# Andorra      [383.0, 563.0, 153.0, 421.0, 193.0, 56.0, 128....           0.0
# Angola       [4.0, 421.0, 191.0, 116.0, 423.0, 11.0, 261.0,...           0.0
# ...                                                        ...           ...
# Venezuela    [620.0, 266.0, 243.0, 805.0, 13.0, 314.0, 699....           1.0
# Vietnam                                                     []           1.0
# Yemen        [244.0, 222.0, 147.0, 2.0, 6.0, 5.0, 7.0, 4.0,...           1.0
# Zambia       [371.0, 1000.0, 230.0, 94.0, 155.0, 442.0, 12....           0.0
# Zimbabwe     [483.0, 38.0, 391.0, 319.0, 311.0, 786.0, 56.0...           0.0
#
#              Annee_souverainete  Political regime
# Pays
# Afghanistan              1919.0               1.0
# Albania                  1912.0               1.0
# Algeria                  1962.0               1.0
# Andorra                     NaN               NaN
# Angola                   1975.0               1.0
# ...                         ...               ...
# Venezuela                1811.0               1.0
# Vietnam                  1945.0               0.0
# Yemen                    1990.0               0.0
# Zambia                   1964.0               1.0
# Zimbabwe                 1965.0               1.0
#
# [198 rows x 5 columns]

# %%
df_nbPrix_musees_anneeSouv_PR_final.reset_index(inplace=True)
df_nbPrix_musees_anneeSouv_PR_final.to_csv("../datasets_merged/df_nbPrix_musees_anneeSouv_PR.csv", index=False)

# %% [markdown]
# ## Merge dataset immigration

# %%
df_imigration=df_imigration.loc[:, ['country','immigrationByCountry_immigrants','immigrationByCountry_emigrants']]
df_imigration.rename(columns={"country":"Pays"}, inplace=True)
df_imigration
# Out:
#                  Pays  immigrationByCountry_immigrants  \
# 0               India                          4878704
# 1               China                          1039675
# 2       United States                         50632836
# 3           Indonesia                           355505
# 4            Pakistan                          3276580
# ..                ...                              ...
# 220        Montserrat                             1379
# 221  Falkland Islands                             1957
# 222              Niue                              588
# 223           Tokelau                             1238
# 224      Vatican City                              809
#
#      immigrationByCountry_emigrants
# 0                          17869492
# 1                          10461170
# 2                           2996223
# 3                           4601369
# 4                           6328400
# ..                              ...
# 220                           24582
# 221                            1518
# 222                            5186
# 223                            2112
# 224                             174
#
# [225 rows x 3 columns]

# %%
df_merged1.reset_index(inplace=True)
df_merged1_imigration=df_merged1.set_index('Pays').join(df_imigration.set_index('Pays'))
df_merged1_imigration_nan=df_merged1_imigration[df_merged1_imigration['immigrationByCountry_immigrants'].isna()]
print("Le nombre de pays sans l'information sur le nombre d'immigrants/émigrés : ",np.sum(df_merged1_imigration_nan['immigrationByCountry_immigrants'].isna()))
df_merged1_imigration_nan
# Out:
# Le nombre de pays sans l'information sur le nombre d'immigrants/émigrés :  7
#                                                                        Notes_musees  \
# Pays
# Antigua and Barbuda                                                         ['4.2']
# Brunei                            ['4,4', '4,0', '4,6', '3,8', '4,5', '3,8', '4,...
# Congo                                    ['4,1', '4,2', '4,4', '3,7', '4,3', '4,6']
# Congo                                    ['4,1', '4,2', '4,4', '3,7', '4,3', '4,6']
# Gambia                                                 ['3.8', '4.0', '4.6', '4.3']
# Saint Vincent and the Grenadines                                     ['4.8', '3.9']
# Taiwan                            ['4.5', '4.5', '4.4', '4.2', '4.4', '4.6', '4....
#
#                                                                NbVotes_musees_clean  \
# Pays
# Antigua and Barbuda                                                         [388.0]
# Brunei                             [821.0, 215.0, 33.0, 68.0, 49.0, 28.0, 2.0, 2.0]
# Congo                                         [230.0, 1000.0, 9.0, 3.0, 87.0, 38.0]
# Congo                                         [230.0, 1000.0, 9.0, 3.0, 87.0, 38.0]
# Gambia                                                    [144.0, 52.0, 25.0, 82.0]
# Saint Vincent and the Grenadines                                      [19.0, 154.0]
# Taiwan                            [9095.0, 4000.0, 5146.0, 627.0, 8490.0, 2470.0...
#
#                                   Nb_prixNobel  Annee_souverainete  \
# Pays
# Antigua and Barbuda                        0.0                 NaN
# Brunei                                     0.0              1984.0
# Congo                                      1.0              1960.0
# Congo                                      1.0              1884.0
# Gambia                                     0.0              1965.0
# Saint Vincent and the Grenadines           0.0                 NaN
# Taiwan                                     1.0              1949.0
#
#                                   Political regime  \
# Pays
# Antigua and Barbuda                            NaN
# Brunei                                         NaN
# Congo                                          1.0
# Congo                                          1.0
# Gambia                                         2.0
# Saint Vincent and the Grenadines               NaN
# Taiwan                                         3.0
#
#                                   immigrationByCountry_immigrants  \
# Pays
# Antigua and Barbuda                                           NaN
# Brunei                                                        NaN
# Congo                                                         NaN
# Congo                                                         NaN
# Gambia                                                        NaN
# Saint Vincent and the Grenadines                              NaN
# Taiwan                                                        NaN
#
#                                   immigrationByCountry_emigrants
# Pays
# Antigua and Barbuda                                          NaN
# Brunei                                                       NaN
# Congo                                                        NaN
# Congo                                                        NaN
# Gambia                                                       NaN
# Saint Vincent and the Grenadines                             NaN
# Taiwan                                                       NaN

# %%
df_imigration[df_imigration.Pays=="DR Congo"]
# Out:
#         Pays  immigrationByCountry_immigrants  immigrationByCountry_emigrants
# 14  DR Congo                           952871                         1832069

# %%
df_imigration.loc[df_imigration['Pays'] == 'DR Congo', 'Pays'] = 'Congo'
df_imigration
# Out:
#                  Pays  immigrationByCountry_immigrants  \
# 0               India                          4878704
# 1               China                          1039675
# 2       United States                         50632836
# 3           Indonesia                           355505
# 4            Pakistan                          3276580
# ..                ...                              ...
# 220        Montserrat                             1379
# 221  Falkland Islands                             1957
# 222              Niue                              588
# 223           Tokelau                             1238
# 224      Vatican City                              809
#
#      immigrationByCountry_emigrants
# 0                          17869492
# 1                          10461170
# 2                           2996223
# 3                           4601369
# 4                           6328400
# ..                              ...
# 220                           24582
# 221                            1518
# 222                            5186
# 223                            2112
# 224                             174
#
# [225 rows x 3 columns]

# %%
#df_merged1.reset_index(inplace=True)
df_nbPrix_musees_anneeSouv_PR_imig=df_merged1.set_index('Pays').join(df_imigration.set_index('Pays'))
print("Le nombre de pays sans l'information sur le nombre d'immigrants/émigrés : ",np.sum(df_nbPrix_musees_anneeSouv_PR_imig['immigrationByCountry_immigrants'].isna()))
# Out:
# Le nombre de pays sans l'information sur le nombre d'immigrants/émigrés :  5

# %%
df_nbPrix_musees_anneeSouv_PR_imig
# Out:
#                                                   Notes_musees  \
# Pays
# Afghanistan                                              [4.5]
# Albania      ['4,1', '4,4', '4,6', '4,6', '4,4', '4,7', '4,...
# Algeria      ['4,4', '4,6', '4,4', '4,3', '4,7', '4,6', '4,...
# Andorra      ['4,5', '4,5', '4,6', '4,4', '4,5', '4,7', '4,...
# Angola       ['4,8', '4,2', '4,1', '3,9', '4,3', '4,5', '4,...
# ...                                                        ...
# Venezuela    ['4,2', '4,5', '4,4', '4,3', '4,7', '4,2', '4,...
# Vietnam                                                     []
# Yemen        ['4.4', '4.4', '4.2', '5.0', '5.0', '4.8', '4....
# Zambia       ['4.3', '4.2', '3.7', '4.3', '3.8', '3.9', '3....
# Zimbabwe     ['3.8', '4.1', '4.3', '3.8', '4.1', '4.0', '4....
#
#                                           NbVotes_musees_clean  Nb_prixNobel  \
# Pays
# Afghanistan                                            [574.0]           0.0
# Albania      [1000.0, 1000.0, 471.0, 1000.0, 3000.0, 259.0,...           0.0
# Algeria      [250.0, 545.0, 790.0, 199.0, 170.0, 348.0, 240...           2.0
# Andorra      [383.0, 563.0, 153.0, 421.0, 193.0, 56.0, 128....           0.0
# Angola       [4.0, 421.0, 191.0, 116.0, 423.0, 11.0, 261.0,...           0.0
# ...                                                        ...           ...
# Venezuela    [620.0, 266.0, 243.0, 805.0, 13.0, 314.0, 699....           1.0
# Vietnam                                                     []           1.0
# Yemen        [244.0, 222.0, 147.0, 2.0, 6.0, 5.0, 7.0, 4.0,...           1.0
# Zambia       [371.0, 1000.0, 230.0, 94.0, 155.0, 442.0, 12....           0.0
# Zimbabwe     [483.0, 38.0, 391.0, 319.0, 311.0, 786.0, 56.0...           0.0
#
#              Annee_souverainete  Political regime  \
# Pays
# Afghanistan              1919.0               1.0
# Albania                  1912.0               1.0
# Algeria                  1962.0               1.0
# Andorra                     NaN               NaN
# Angola                   1975.0               1.0
# ...                         ...               ...
# Venezuela                1811.0               1.0
# Vietnam                  1945.0               0.0
# Yemen                    1990.0               0.0
# Zambia                   1964.0               1.0
# Zimbabwe                 1965.0               1.0
#
#              immigrationByCountry_immigrants  immigrationByCountry_emigrants
# Pays
# Afghanistan                         144098.0                       5853838.0
# Albania                              48810.0                       1250451.0
# Algeria                             250378.0                       2022337.0
# Andorra                              45574.0                         11132.0
# Angola                              656434.0                        668066.0
# ...                                      ...                             ...
# Venezuela                          1324193.0                       5415337.0
# Vietnam                              76767.0                       3392025.0
# Yemen                               387113.0                       1301166.0
# Zambia                              187955.0                        200700.0
# Zimbabwe                            416141.0                       1243314.0
#
# [198 rows x 7 columns]

# %%
df_nbPrix_musees_anneeSouv_PR_imig.reset_index(inplace=True)
df_merged2=df_nbPrix_musees_anneeSouv_PR_imig.copy()

# %%
df_nbPrix_musees_anneeSouv_PR_imig.to_csv("../datasets_merged/df_nbPrix_musees_anneeSouv_PR_imig.csv", index=False)
