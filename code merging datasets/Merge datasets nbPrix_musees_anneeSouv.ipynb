# %%
import pandas as pd
import numpy as np

# %%
# importer les datasets a merge
df_pays_anneeSouv=pd.read_csv("../datasets_scraped/df_pays_anneeSouv.csv")
df_pays_musees=pd.read_csv("../datasets_scraped/df_pays_musees.csv")
df_pays_nbPrix=pd.read_csv("../datasets_scraped/df_pays_nbPrix.csv")
df_pays_CategoriePrixNobel=pd.read_csv("../datasets_scraped/df_pays_CategoriePrixNobel.csv")

# %% [markdown]
# ## Etudier les differences entre les datasets des prix nobels

# %%
# Etudier les differences entre df_pays_CategoriePrixNobel et df_pays_nbPrix (les pays non référencés dans l'un ou l'autre des datasets)
df_pays_nbPrix2=df_pays_CategoriePrixNobel.groupby('Pays').count()
df_pays_nbPrix2.rename(columns={"CategoriePrixNobel":"nbPrix"}, inplace=True)
df_nbPrix_diff=df_pays_nbPrix2.join(df_pays_nbPrix.set_index('Pays'))

df_nbPrix_diff_nan=df_nbPrix_diff[df_nbPrix_diff['Nb_prixNobel'].isna()]
df_nbPrix_diff_nan
# Out:
#                                     nbPrix  Nb_prixNobel
# Pays
# Armenia                                  1           NaN
# Brazil                                   1           NaN
# China (People's Republic of China)       8           NaN
# Congo, Democratic Republic               1           NaN
# Ireland                                 11           NaN
# Myanmar (Burma)                          1           NaN
# Palestine                                1           NaN
# Russia and Soviet Union                 30           NaN
# Yugoslavia                               3           NaN

# %%
df_nbPrix_diff2=df_pays_nbPrix.set_index('Pays').join(df_pays_nbPrix2)

df_nbPrix_diff2_nan=df_nbPrix_diff2[df_nbPrix_diff2['nbPrix'].isna()]
df_nbPrix_diff2_nan
# Out:
#                                           Nb_prixNobel  nbPrix
# Pays
# Russia                                              30     NaN
# Republic of Ireland                                 11     NaN
# China                                                8     NaN
# Algeria                                              2     NaN
# Democratic Republic of the Congo                     1     NaN
# Myanmar                                              1     NaN
# State of Palestine                                   1     NaN
# Socialist Federal Republic of Yugoslavia             3     NaN

# %%
df_pays_nbPrix2.reset_index(inplace=True)
df_pays_nbPrix2.rename(columns={"nbPrix":"Nb_prixNobel"}, inplace=True)
df_pays_nbPrix_final=pd.concat([df_pays_nbPrix,df_pays_nbPrix2[df_pays_nbPrix2.Pays.isin(['Armenia','Brazil'])]],ignore_index=True)
df_pays_nbPrix_final
# Out:
#                                         Pays  Nb_prixNobel
# 0                              United States           411
# 1                             United Kingdom           137
# 2                                    Germany           115
# 3                                     France            75
# 4                                     Sweden            34
# ..                                       ...           ...
# 78                                   Vietnam             1
# 79                                     Yemen             1
# 80  Socialist Federal Republic of Yugoslavia             3
# 81                                   Armenia             1
# 82                                    Brazil             1
#
# [83 rows x 2 columns]

# %% [markdown]
# ## Combiner les datasets relatifs à nbPrix et musée

# %% [markdown]
# ### Identifier les pays en communs et traiter les mal étiquetés

# %%
df_merged1=df_pays_musees.set_index('Pays').join(df_pays_nbPrix_final.set_index('Pays'))
df_merged1
# Out:
#                                                                Notes_musees  \
# Pays
# India                     ['4.6', '4.5', '4.4', '4.6', '4.6', '4.3', '4....
# China                     ['4.3', '4.4', '4.6', '4.5', '4.3', '4.4', '4....
# United States             ['4.3', '4.5', '4.8', '4.8', '4.8', '4.8', '4....
# Indonesia                 ['4,7', '4,5', '4,5', '4,6', '4,3', '4,7', '4,...
# Pakistan                  ['4.3', '4.5', '4.5', '4.6', '4.4', '4.4', '4....
# ...                                                                     ...
# Turks and Caicos Islands                ['4.4', '4.6', '5.0', '3.8', '4.6']
# Marshall Islands                                                    ['4.2']
# Liechtenstein             ['4.6', '4.3', '3.7', '4.3', '4.2', '4.3', '4....
# British Virgin Islands                  ['4.7', '4.4', '5.0', '2.5', '3.8']
# Cook Islands                                   ['4.5', '4.8', '4.0', '4.4']
#
#                                                        NbVotes_musees_clean  \
# Pays
# India                     [18000.0, 49000.0, 69000.0, 34000.0, 74000.0, ...
# China                     [398.0, 925.0, 1000.0, 236.0, 154.0, 451.0, 38...
# United States             [373.0, 19000.0, 46000.0, 30000.0, 32000.0, 16...
# Indonesia                 [1000.0, 157000.0, 19.0, 22000.0, 205.0, 9000....
# Pakistan                  [1000.0, 4000.0, 8000.0, 13000.0, 12000.0, 400...
# ...                                                                     ...
# Turks and Caicos Islands                       [187.0, 36.0, 4.0, 9.0, 7.0]
# Marshall Islands                                                     [34.0]
# Liechtenstein             [280.0, 645.0, 64.0, 260.0, 17.0, 22.0, 18.0, ...
# British Virgin Islands                           [26.0, 7.0, 1.0, 2.0, 5.0]
# Cook Islands                                       [103.0, 9.0, 32.0, 42.0]
#
#                           Nb_prixNobel
# Pays
# India                             10.0
# China                              8.0
# United States                    411.0
# Indonesia                          NaN
# Pakistan                           2.0
# ...                                ...
# Turks and Caicos Islands           NaN
# Marshall Islands                   NaN
# Liechtenstein                      NaN
# British Virgin Islands             NaN
# Cook Islands                       NaN
#
# [197 rows x 3 columns]

# %%
df_merged1_nan=df_merged1[df_merged1.Nb_prixNobel.isna()]
df_merged1_nan
# Out:
#                                                                Notes_musees  \
# Pays
# Indonesia                 ['4,7', '4,5', '4,5', '4,6', '4,3', '4,7', '4,...
# Congo                            ['4,1', '4,2', '4,4', '3,7', '4,3', '4,6']
# Thailand                  ['4.5', '4.3', '4.6', '4.5', '4.6', '4.6', '4....
# Uganda                                  ['4.1', '4.6', '4.1', '4.7', '4.4']
# Sudan                     ['4.3', '4.3', '4.4', '4.1', '4.2', '4.1', '4.0']
# ...                                                                     ...
# Turks and Caicos Islands                ['4.4', '4.6', '5.0', '3.8', '4.6']
# Marshall Islands                                                    ['4.2']
# Liechtenstein             ['4.6', '4.3', '3.7', '4.3', '4.2', '4.3', '4....
# British Virgin Islands                  ['4.7', '4.4', '5.0', '2.5', '3.8']
# Cook Islands                                   ['4.5', '4.8', '4.0', '4.4']
#
#                                                        NbVotes_musees_clean  \
# Pays
# Indonesia                 [1000.0, 157000.0, 19.0, 22000.0, 205.0, 9000....
# Congo                                 [230.0, 1000.0, 9.0, 3.0, 87.0, 38.0]
# Thailand                  [6000.0, 376.0, 397.0, 1000.0, 6000.0, 2000.0,...
# Uganda                                    [2000.0, 10.0, 921.0, 66.0, 38.0]
# Sudan                          [106.0, 163.0, 16.0, 41.0, 270.0, 54.0, 3.0]
# ...                                                                     ...
# Turks and Caicos Islands                       [187.0, 36.0, 4.0, 9.0, 7.0]
# Marshall Islands                                                     [34.0]
# Liechtenstein             [280.0, 645.0, 64.0, 260.0, 17.0, 22.0, 18.0, ...
# British Virgin Islands                           [26.0, 7.0, 1.0, 2.0, 5.0]
# Cook Islands                                       [103.0, 9.0, 32.0, 42.0]
#
#                           Nb_prixNobel
# Pays
# Indonesia                          NaN
# Congo                              NaN
# Thailand                           NaN
# Uganda                             NaN
# Sudan                              NaN
# ...                                ...
# Turks and Caicos Islands           NaN
# Marshall Islands                   NaN
# Liechtenstein                      NaN
# British Virgin Islands             NaN
# Cook Islands                       NaN
#
# [122 rows x 3 columns]

# %%
def has_common_name(liste_mots1, liste_mots2):
    
    liste_mots_communs=set()

    # Vérifier si on a au moins un mot en commun
    for mot in liste_mots1:
        if mot in liste_mots2:
            liste_mots_communs.add(mot)
    return liste_mots_communs

df_merged1_nan.reset_index(inplace=True)
liste_pays1=list(df_merged1_nan.Pays.apply(lambda x : x.split()))
liste_pays1=[mot for sublist in liste_pays1 for mot in sublist]

liste_pays2=list(df_pays_nbPrix_final.Pays.apply(lambda x : x.split()))
liste_pays2=[mot for sublist in liste_pays2 for mot in sublist]

liste_mots_communs=has_common_name(liste_pays1,liste_pays2)
liste_mots_communs
# Out:
# {'Congo',
#  'Ireland',
#  'Islands',
#  'Korea',
#  'New',
#  'North',
#  'Palestine',
#  'Republic',
#  'Saint',
#  'South',
#  'United',
#  'and',
#  'of',
#  'the'}

# %%
# Mettre a jour le nom des pays de sorte à ce qu'ils correspondent à ceux du dataset musée
dict_convertNomPays={"Democratic Republic of the Congo":"Congo", "Republic of Ireland": "Ireland","State of Palestine":'Palestine'}
df_pays_nbPrix_final.Pays=df_pays_nbPrix_final.Pays.apply(lambda x : dict_convertNomPays[x] if x in dict_convertNomPays else x)
df_pays_nbPrix_final[df_pays_nbPrix_final.Pays=='Congo']
# Out:
#      Pays  Nb_prixNobel
# 55  Congo             1

# %%
df_merged1=df_pays_musees.set_index('Pays').join(df_pays_nbPrix_final.set_index('Pays'))
print("Le nombre de pays sans prix Nobel : ",np.sum(df_merged1.Nb_prixNobel.isna()))
# Remplacer les NaN par des 0=nombre de prix nobel
df_merged1.Nb_prixNobel=df_merged1.Nb_prixNobel.fillna(0)
df_merged1
# Out:
# Le nombre de pays sans prix Nobel :  119
#                                                                Notes_musees  \
# Pays
# India                     ['4.6', '4.5', '4.4', '4.6', '4.6', '4.3', '4....
# China                     ['4.3', '4.4', '4.6', '4.5', '4.3', '4.4', '4....
# United States             ['4.3', '4.5', '4.8', '4.8', '4.8', '4.8', '4....
# Indonesia                 ['4,7', '4,5', '4,5', '4,6', '4,3', '4,7', '4,...
# Pakistan                  ['4.3', '4.5', '4.5', '4.6', '4.4', '4.4', '4....
# ...                                                                     ...
# Turks and Caicos Islands                ['4.4', '4.6', '5.0', '3.8', '4.6']
# Marshall Islands                                                    ['4.2']
# Liechtenstein             ['4.6', '4.3', '3.7', '4.3', '4.2', '4.3', '4....
# British Virgin Islands                  ['4.7', '4.4', '5.0', '2.5', '3.8']
# Cook Islands                                   ['4.5', '4.8', '4.0', '4.4']
#
#                                                        NbVotes_musees_clean  \
# Pays
# India                     [18000.0, 49000.0, 69000.0, 34000.0, 74000.0, ...
# China                     [398.0, 925.0, 1000.0, 236.0, 154.0, 451.0, 38...
# United States             [373.0, 19000.0, 46000.0, 30000.0, 32000.0, 16...
# Indonesia                 [1000.0, 157000.0, 19.0, 22000.0, 205.0, 9000....
# Pakistan                  [1000.0, 4000.0, 8000.0, 13000.0, 12000.0, 400...
# ...                                                                     ...
# Turks and Caicos Islands                       [187.0, 36.0, 4.0, 9.0, 7.0]
# Marshall Islands                                                     [34.0]
# Liechtenstein             [280.0, 645.0, 64.0, 260.0, 17.0, 22.0, 18.0, ...
# British Virgin Islands                           [26.0, 7.0, 1.0, 2.0, 5.0]
# Cook Islands                                       [103.0, 9.0, 32.0, 42.0]
#
#                           Nb_prixNobel
# Pays
# India                             10.0
# China                              8.0
# United States                    411.0
# Indonesia                          0.0
# Pakistan                           2.0
# ...                                ...
# Turks and Caicos Islands           0.0
# Marshall Islands                   0.0
# Liechtenstein                      0.0
# British Virgin Islands             0.0
# Cook Islands                       0.0
#
# [197 rows x 3 columns]

# %%
df_musees_nbPrix=df_merged1.copy()

# %% [markdown]
# ## Combiner les datasets anneeSouv et nbPrix_musées

# %%
df_merged2=df_musees_nbPrix.join(df_pays_anneeSouv.set_index('Pays'))
df_merged2
# Out:
#                                                                Notes_musees  \
# Pays
# India                     ['4.6', '4.5', '4.4', '4.6', '4.6', '4.3', '4....
# China                     ['4.3', '4.4', '4.6', '4.5', '4.3', '4.4', '4....
# United States             ['4.3', '4.5', '4.8', '4.8', '4.8', '4.8', '4....
# Indonesia                 ['4,7', '4,5', '4,5', '4,6', '4,3', '4,7', '4,...
# Pakistan                  ['4.3', '4.5', '4.5', '4.6', '4.4', '4.4', '4....
# ...                                                                     ...
# Turks and Caicos Islands                ['4.4', '4.6', '5.0', '3.8', '4.6']
# Marshall Islands                                                    ['4.2']
# Liechtenstein             ['4.6', '4.3', '3.7', '4.3', '4.2', '4.3', '4....
# British Virgin Islands                  ['4.7', '4.4', '5.0', '2.5', '3.8']
# Cook Islands                                   ['4.5', '4.8', '4.0', '4.4']
#
#                                                        NbVotes_musees_clean  \
# Pays
# India                     [18000.0, 49000.0, 69000.0, 34000.0, 74000.0, ...
# China                     [398.0, 925.0, 1000.0, 236.0, 154.0, 451.0, 38...
# United States             [373.0, 19000.0, 46000.0, 30000.0, 32000.0, 16...
# Indonesia                 [1000.0, 157000.0, 19.0, 22000.0, 205.0, 9000....
# Pakistan                  [1000.0, 4000.0, 8000.0, 13000.0, 12000.0, 400...
# ...                                                                     ...
# Turks and Caicos Islands                       [187.0, 36.0, 4.0, 9.0, 7.0]
# Marshall Islands                                                     [34.0]
# Liechtenstein             [280.0, 645.0, 64.0, 260.0, 17.0, 22.0, 18.0, ...
# British Virgin Islands                           [26.0, 7.0, 1.0, 2.0, 5.0]
# Cook Islands                                       [103.0, 9.0, 32.0, 42.0]
#
#                           Nb_prixNobel  Annee_souverainete
# Pays
# India                             10.0              1947.0
# China                              8.0                 NaN
# United States                    411.0                 NaN
# Indonesia                          0.0              1945.0
# Pakistan                           2.0              1947.0
# ...                                ...                 ...
# Turks and Caicos Islands           0.0                 NaN
# Marshall Islands                   0.0              1986.0
# Liechtenstein                      0.0              1813.0
# British Virgin Islands             0.0                 NaN
# Cook Islands                       0.0                 NaN
#
# [197 rows x 4 columns]

# %%
# Analyser le nombre de pays pour lesquels on a pas d'annee de souverainete
print("Le nombre de pays sans annee de souverainte : ",np.sum(df_merged2.Annee_souverainete.isna()))
df_merged2_nan=df_merged2[df_merged2.Annee_souverainete.isna()]
df_merged2_nan
# Out:
# Le nombre de pays sans annee de souverainte :  40
#                                                                        Notes_musees  \
# Pays
# China                             ['4.3', '4.4', '4.6', '4.5', '4.3', '4.4', '4....
# United States                     ['4.3', '4.5', '4.8', '4.8', '4.8', '4.8', '4....
# Congo                                    ['4,1', '4,2', '4,4', '3,7', '4,3', '4,6']
# Vietnam                                                                          []
# Turkey                                                                           []
# Myanmar                           ['4,2', '4,3', '4,6', '4,2', '4,4', '4,1', '4,...
# Ecuador                           ['4,6', '4,7', '4,7', '4,6', '4,6', '4,8', '4,...
# Netherlands                       ['4,6', '4,3', '4,6', '4,5', '4,6', '4,5', '4,...
# Benin                             ['4,3', '3,6', '3,9', '3,9', '3,9', '4,2', '4,...
# Tajikistan                                                                       []
# Switzerland                       ['4.4', '4.5', '4.6', '4.5', '4.6', '4.7', '4....
# Hong Kong                         ['4.4', '4.3', '4.4', '4.2', '4.4', '4.3', '4....
# Kyrgyzstan                                                                       []
# El Salvador                       ['4.7', '4.6', '4.7', '4.7', '4.6', '4.5', '4....
# Republic of the Congo                                         ['4,1', '4,6', '4,3']
# Palestine                         [4.3, 4.8, 4.4, 4.5, 4.3, 4.6, 4.4, 4.7, 4.7, ...
# Puerto Rico                       ['4.7', '4.6', '4.6', '4.6', '4.7', '4.5', '4....
# North Macedonia                   ['4,0', '4,1', '4,4', '4,2', '4,3', '4,4', '4,...
# Eswatini                                                             ['4.1', '3.2']
# Bhutan                            ['4.3', '4.2', '4.4', '4.3', '4.4', '4.7', '4....
# Macau                             ['4,2', '4,3', '3,7', '4,0', '4,4', '4,2', '4,...
# Suriname                          ['4,3', '4,3', '4,4', '5,0', '3,6', '4,5', '5,...
# Cape Verde                        ['4,8', '4,3', '4,0', '5,0', '4,3', '4,5', '4,...
# New Caledonia                     ['4,3', '4,4', '4,5', '3,9', '4,6', '4,5', '4,...
# Barbados                                                                    ['4.3']
# Saint Lucia                       ['4.0', '4.2', '5.0', '4.6', '4.0', '4.2', '4....
# Grenada                                                ['4.1', '4.2', '4.5', '4.2']
# Micronesia                        ['4.1', '4.4', '4.6', '3.5', '5.0', '4.3', '4.3']
# Saint Vincent and the Grenadines                                     ['4.8', '3.9']
# Antigua and Barbuda                                                         ['4.2']
# Andorra                           ['4,5', '4,5', '4,6', '4,4', '4,5', '4,7', '4,...
# Dominica                                                                    ['4.3']
# Cayman Islands                                                       ['4.5', '4.6']
# Bermuda                           ['4.6', '4.6', '4.3', '4.3', '4.7', '4.6', '4....
# Greenland                         ['4,5', '4,3', '4,1', '4,5', '4,8', '4,0', '4,...
# Northern Mariana Islands                                                    ['4.4']
# Saint Kitts and Nevis                           ['4.4', '4.6', '4.8', '4.6', '3.5']
# Turks and Caicos Islands                        ['4.4', '4.6', '5.0', '3.8', '4.6']
# British Virgin Islands                          ['4.7', '4.4', '5.0', '2.5', '3.8']
# Cook Islands                                           ['4.5', '4.8', '4.0', '4.4']
#
#                                                                NbVotes_musees_clean  \
# Pays
# China                             [398.0, 925.0, 1000.0, 236.0, 154.0, 451.0, 38...
# United States                     [373.0, 19000.0, 46000.0, 30000.0, 32000.0, 16...
# Congo                                         [230.0, 1000.0, 9.0, 3.0, 87.0, 38.0]
# Vietnam                                                                          []
# Turkey                                                                           []
# Myanmar                           [1000.0, 473.0, 175.0, 571.0, 11.0, 78.0, 15.0...
# Ecuador                           [1000.0, 2000.0, 2000.0, 1000.0, 638.0, 885.0,...
# Netherlands                       [90000.0, 5000.0, 83000.0, 10000.0, 17000.0, 6...
# Benin                             [427.0, 106.0, 1000.0, 332.0, 335.0, 359.0, 6....
# Tajikistan                                                                       []
# Switzerland                       [2079.0, 7897.0, 6351.0, 2228.0, 3910.0, 1203....
# Hong Kong                         [3030.0, 6812.0, 7622.0, 615.0, 2298.0, 2922.0...
# Kyrgyzstan                                                                       []
# El Salvador                       [2000.0, 1000.0, 132.0, 295.0, 2000.0, 3000.0,...
# Republic of the Congo                                           [230.0, 38.0, 87.0]
# Palestine                         [386.0, 49.0, 132.0, 440.0, 270.0, 717.0, 36.0...
# Puerto Rico                       [2000.0, 559.0, 765.0, 559.0, 2000.0, 300.0, 3...
# North Macedonia                   [138.0, 1000.0, 858.0, 422.0, 96.0, 2000.0, 53...
# Eswatini                                                                [65.0, 5.0]
# Bhutan                            [1000.0, 621.0, 943.0, 405.0, 33.0, 35.0, 7.0,...
# Macau                             [491.0, 248.0, 30.0, 470.0, 23.0, 183.0, 60.0,...
# Suriname                          [30.0, 370.0, 49.0, 7.0, 20.0, 20.0, 1.0, 38.0...
# Cape Verde                        [147.0, 4.0, 117.0, 20.0, 48.0, 115.0, 41.0, 8...
# New Caledonia                     [86.0, 668.0, 112.0, 9.0, 121.0, 4.0, 32.0, 11...
# Barbados                                                                    [729.0]
# Saint Lucia                       [6.0, 14.0, 1.0, 13.0, 26.0, 47.0, 3.0, 144.0,...
# Grenada                                                   [58.0, 12.0, 13.0, 114.0]
# Micronesia                                 [7.0, 49.0, 263.0, 2.0, 1.0, 7.0, 354.0]
# Saint Vincent and the Grenadines                                      [19.0, 154.0]
# Antigua and Barbuda                                                         [388.0]
# Andorra                           [383.0, 563.0, 153.0, 421.0, 193.0, 56.0, 128....
# Dominica                                                                     [65.0]
# Cayman Islands                                                       [232.0, 130.0]
# Bermuda                           [691.0, 8.0, 21.0, 12.0, 22.0, 34.0, 257.0, 8....
# Greenland                         [282.0, 197.0, 11.0, 33.0, 43.0, 18.0, 9.0, 28...
# Northern Mariana Islands                                                     [70.0]
# Saint Kitts and Nevis                               [110.0, 64.0, 151.0, 21.0, 6.0]
# Turks and Caicos Islands                               [187.0, 36.0, 4.0, 9.0, 7.0]
# British Virgin Islands                                   [26.0, 7.0, 1.0, 2.0, 5.0]
# Cook Islands                                               [103.0, 9.0, 32.0, 42.0]
#
#                                   Nb_prixNobel  Annee_souverainete
# Pays
# China                                      8.0                 NaN
# United States                            411.0                 NaN
# Congo                                      1.0                 NaN
# Vietnam                                    1.0                 NaN
# Turkey                                     2.0                 NaN
# Myanmar                                    1.0                 NaN
# Ecuador                                    0.0                 NaN
# Netherlands                               22.0                 NaN
# Benin                                      0.0                 NaN
# Tajikistan                                 0.0                 NaN
# Switzerland                               25.0                 NaN
# Hong Kong                                  1.0                 NaN
# Kyrgyzstan                                 0.0                 NaN
# El Salvador                                0.0                 NaN
# Republic of the Congo                      0.0                 NaN
# Palestine                                  1.0                 NaN
# Puerto Rico                                0.0                 NaN
# North Macedonia                            1.0                 NaN
# Eswatini                                   0.0                 NaN
# Bhutan                                     0.0                 NaN
# Macau                                      0.0                 NaN
# Suriname                                   0.0                 NaN
# Cape Verde                                 0.0                 NaN
# New Caledonia                              0.0                 NaN
# Barbados                                   0.0                 NaN
# Saint Lucia                                2.0                 NaN
# Grenada                                    0.0                 NaN
# Micronesia                                 0.0                 NaN
# Saint Vincent and the Grenadines           0.0                 NaN
# Antigua and Barbuda                        0.0                 NaN
# Andorra                                    0.0                 NaN
# Dominica                                   0.0                 NaN
# Cayman Islands                             0.0                 NaN
# Bermuda                                    0.0                 NaN
# Greenland                                  0.0                 NaN
# Northern Mariana Islands                   0.0                 NaN
# Saint Kitts and Nevis                      0.0                 NaN
# Turks and Caicos Islands                   0.0                 NaN
# British Virgin Islands                     0.0                 NaN
# Cook Islands                               0.0                 NaN

# %%
# Identifier les mots en communs entre le dataset que nous voulons join et celui des pays sans correspondance (retrouver les pays mal etiquetés)
df_merged2_nan.reset_index(inplace=True)
liste_pays1=list(df_merged2_nan.Pays.apply(lambda x : x.split()))
liste_pays1=[mot for sublist in liste_pays1 for mot in sublist]

liste_pays2=list(df_pays_anneeSouv.Pays.apply(lambda x : x.split()))
liste_pays2=[mot for sublist in liste_pays2 for mot in sublist]

liste_mots_communs=has_common_name(liste_pays1,liste_pays2)
liste_mots_communs
# Out:
# {'China',
#  'Congo',
#  'Eswatini',
#  'Islands',
#  'Macedonia',
#  'Netherlands',
#  'New',
#  'North',
#  'Republic',
#  'Salvador',
#  'United',
#  'Vietnam',
#  'and',
#  'of'}

# %%
# Mettre a jour le nom des pays de sorte à ce qu'ils correspondent à ceux du dataset nbPrix_musée
dict_convertNomPays={"People's Republic of China":"China", "Republic of Congo": "Congo","Democratic Republic of Congo":'Congo', "Vietnam Vietnam":"Vietnam",
                     "Eswatini / Swaziland":"Eswatini", "North Macedonia":"Macedonia", "The Netherlands": "Netherlands", "Salvador":"El Salvador"}
df_pays_anneeSouv.Pays=df_pays_anneeSouv.Pays.apply(lambda x : dict_convertNomPays[x] if x in dict_convertNomPays else x)
df_pays_anneeSouv[df_pays_anneeSouv.Pays=='Netherlands']
# Out:
#             Pays  Annee_souverainete
# 165  Netherlands                1945

# %%
df_merged2=df_musees_nbPrix.join(df_pays_anneeSouv.set_index('Pays'))
print("Le nombre de pays sans annee de souverainte : ",np.sum(df_merged2.Annee_souverainete.isna()))
df_nbPrix_musees_anneeSouv=df_merged2.copy()
df_nbPrix_musees_anneeSouv=df_nbPrix_musees_anneeSouv.reset_index()
# Out:
# Le nombre de pays sans annee de souverainte :  34

# %%
df_nbPrix_musees_anneeSouv.to_csv("../datasets_scraped/df_nbPrix_musees_anneeSouv.csv", index=False)
